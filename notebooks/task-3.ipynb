# %% [markdown]
# ## --------------------
# ## Database creation
# ## --------------------

# %%
# %run ../src/database/task_3_database_storage.py
# Out:
# 2025-11-27 15:48:02,504 - INFO - Loaded 1884 enriched reviews for database storage.
# 2025-11-27 15:48:02,679 - INFO - Successfully connected to PostgreSQL database.
# 2025-11-27 15:48:02,681 - INFO - Creating 'banks' table...
# 2025-11-27 15:48:02,700 - INFO - Creating 'reviews' table...
# 2025-11-27 15:48:02,719 - INFO - Database schema creation complete.
# 2025-11-27 15:48:02,723 - INFO - Inserting 3 unique bank entries...
# 2025-11-27 15:48:02,734 - INFO - Bank ID mapping created: {'BOA': 1, 'CBE': 2, 'Dashen': 3}
# 2025-11-27 15:48:02,736 - INFO - Preparing reviews data for bulk insertion...
# 2025-11-27 15:48:02,770 - INFO - Starting bulk insertion of 1884 review records...
# 2025-11-27 15:48:02,913 - INFO - Bulk insertion complete.
# 2025-11-27 15:48:02,915 - INFO -
# ✨ Task 3: Data successfully loaded into PostgreSQL.
# 2025-11-27 15:48:02,917 - INFO - PostgreSQL connection closed.
