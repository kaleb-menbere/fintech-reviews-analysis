# %% [markdown]
# ## --------------------
# ## Database creation
# ## --------------------

# %%
# %run ../src/database/task_3_database_storage.py
# Out:
# 2025-11-27 16:16:52,941 - INFO - Loaded 1884 enriched reviews for database storage.
# 2025-11-27 16:16:53,121 - INFO - Successfully connected to PostgreSQL database.
# 2025-11-27 16:16:53,122 - INFO - Creating 'banks' table...
# 2025-11-27 16:16:53,127 - INFO - Creating 'reviews' table...
# 2025-11-27 16:16:53,130 - INFO - Database schema creation complete.
# 2025-11-27 16:16:53,135 - INFO - Inserting 3 unique bank entries...
# 2025-11-27 16:16:53,145 - INFO - Bank ID mapping created: {'BOA': 1, 'CBE': 2, 'Dashen': 3}
# 2025-11-27 16:16:53,147 - INFO - Preparing reviews data for bulk insertion...
# 2025-11-27 16:16:53,179 - INFO - Starting bulk insertion of 1884 review records...
# 2025-11-27 16:16:53,255 - INFO - Bulk insertion complete.
# 2025-11-27 16:16:53,256 - INFO -
# ✨ Task 3: Data successfully loaded into PostgreSQL.
# 2025-11-27 16:16:53,258 - INFO - PostgreSQL connection closed.
