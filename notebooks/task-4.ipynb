# %%
# %run ../src/analysis/task_4_analysis.py
# Out:
# 2025-11-27 16:31:34,250 - INFO - Successfully connected to PostgreSQL for Task 4 analysis.
# 2025-11-27 16:31:34,283 - INFO - Extracted 1884 themed records for analysis.
# 2025-11-27 16:31:34,285 - INFO - Generating Monthly Sentiment Trend Plot...
# C:\Users\ADMIN\Desktop\KALEB\10Academy\Week2\fintech-reviews-analysis\src\analysis\task_4_analysis.py:251: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
# C:\Users\ADMIN\Desktop\KALEB\10Academy\Week2\fintech-reviews-analysis\src\analysis\task_4_analysis.py:252: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
# ...
